# %% [markdown]
# # Busara

# %%
# importing the libraries we're going to be using.
from fastai.imports import *
from fastai.structured import *

from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display

from sklearn import metrics
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-1cb596263e7a> in <module>()
#       1 # importing the libraries we're going to be using.
# ----> 2 from fastai.imports import *
#       3 from fastai.structured import *
#       4
#       5 from pandas_summary import DataFrameSummary
#
# /media/muoki/data/documents/code_training/portfolio/DataScienceProjects/busara/fastai/__init__.py in <module>()
# ----> 1 from .basic_train import *
#       2 from .callback import *
#       3 #from .callbacks import *
#       4 from .core import *
#       5 from .basic_data import *
#
# /media/muoki/data/documents/code_training/portfolio/DataScienceProjects/busara/fastai/basic_train.py in <module>()
#       1 "Provides basic training and validation with `Learner`"
# ----> 2 from .torch_core import *
#       3 from .basic_data import *
#       4 from .callback import *
#       5
#
# /media/muoki/data/documents/code_training/portfolio/DataScienceProjects/busara/fastai/torch_core.py in <module>()
#       1 "Utility functions to help deal with tensors"
# ----> 2 from .imports.torch import *
#       3 from .core import *
#       4
#       5 AffineMatrix = Tensor
#
# /media/muoki/data/documents/code_training/portfolio/DataScienceProjects/busara/fastai/imports/__init__.py in <module>()
# ----> 1 from .core import *
#       2 from .torch import *
#
# /media/muoki/data/documents/code_training/portfolio/DataScienceProjects/busara/fastai/imports/core.py in <module>()
#      10 from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor
#      11 from copy import copy, deepcopy
# ---> 12 from dataclasses import dataclass, field
#      13 from enum import Enum, IntEnum
#      14 from fastprogress import master_bar, progress_bar
#
# ModuleNotFoundError: No module named 'dataclasses'

# %%
# !pip install dataclasses
# Out:
# Collecting dataclasses
#   Using cached https://files.pythonhosted.org/packages/26/2f/1095cdc2868052dd1e64520f7c0d5c8c550ad297e944e641dbf1ffbb9a5d/dataclasses-0.6-py3-none-any.whl

# %%
df_raw = pd.read_csv(f'train.csv', low_memory=False, 
                     parse_dates=["survey_date"])

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %%
df_raw.head(10).T
# Out:
#                                            0                    1  \
# surveyid                                 926                  747
# village                                   91                   57
# survey_date              2061-11-23 00:00:00  2061-10-24 00:00:00
# femaleres                                  1                    1
# age                                       28                   23
# married                                    1                    1
# children                                   4                    3
# hhsize                                     6                    5
# edu                                       10                    8
# hh_children                                0                    0
# hh_totalmembers                          NaN                  NaN
# cons_nondurable                            0                    0
# asset_livestock                            0                    0
# asset_durable                              0                    0
# asset_phone                                0                    0
# asset_savings                              0                    0
# asset_land_owned_total                     0                    0
# asset_niceroof                             0                    0
# cons_allfood                               0                    0
# cons_ownfood                               0                    0
# cons_alcohol                               0                    0
# cons_tobacco                               0                    0
# cons_med_total                             0                    0
# cons_med_children                        NaN                  NaN
# cons_ed                                    0                    0
# cons_social                                0                    0
# cons_other                                 0                    0
# ent_wagelabor                              0                    0
# ent_ownfarm                                0                    0
# ent_business                               0                    0
# ...                                      ...                  ...
# med_expenses_hh_ep                       NaN                  NaN
# med_expenses_sp_ep                       NaN                  NaN
# med_expenses_child_ep                    NaN                  NaN
# med_portion_sickinjured                  NaN                  NaN
# med_port_sick_child                      NaN                  NaN
# med_afford_port                          NaN                  NaN
# med_sickdays_hhave                       NaN                  NaN
# med_healthconsult                        NaN                  NaN
# med_vacc_newborns                          1                    1
# med_child_check                            1                    1
# med_u5_deaths                            NaN                  NaN
# ed_expenses                              NaN                  NaN
# ed_expenses_perkid                       NaN                  NaN
# ed_schoolattend                          NaN                  NaN
# ed_sch_missedpc                          NaN                  NaN
# ed_work_act_pc                           NaN                  NaN
# labor_primary                              0                    0
# wage_expenditures                          0                    0
# durable_investment                         0                    0
# nondurable_investment                      0                    0
# given_mpesa                                0                    0
# amount_given_mpesa                         0                    0
# received_mpesa                             0                    1
# amount_received_mpesa                      0              4.80461
# net_mpesa                                  0              4.80461
# saved_mpesa                                1                    0
# amount_saved_mpesa                         0                    0
# early_survey                               0                    0
# depressed                                  0                    1
# day_of_week                                5                    3
#
#                                            2                    3  \
# surveyid                                1190                 1065
# village                                  115                   97
# survey_date              2061-10-05 00:00:00  2061-09-23 00:00:00
# femaleres                                  1                    1
# age                                       22                   27
# married                                    1                    1
# children                                   3                    2
# hhsize                                     5                    4
# edu                                        9                   10
# hh_children                                0                    2
# hh_totalmembers                          NaN                    4
# cons_nondurable                            0              378.833
# asset_livestock                            0              526.671
# asset_durable                              0              196.989
# asset_phone                                0              24.0231
# asset_savings                              0              49.6476
# asset_land_owned_total                     0                    0
# asset_niceroof                             0                    0
# cons_allfood                               0              289.174
# cons_ownfood                               0               36.435
# cons_alcohol                               0                    0
# cons_tobacco                               0                    0
# cons_med_total                             0                4.164
# cons_med_children                        NaN             0.960922
# cons_ed                                    0              1.68161
# cons_social                                0              39.7715
# cons_other                                 0              44.0423
# ent_wagelabor                              0                    0
# ent_ownfarm                                0                    1
# ent_business                               0                    0
# ...                                      ...                  ...
# med_expenses_hh_ep                       NaN                  NaN
# med_expenses_sp_ep                       NaN                  NaN
# med_expenses_child_ep                    NaN                  NaN
# med_portion_sickinjured                  NaN                    0
# med_port_sick_child                      NaN                    0
# med_afford_port                          NaN                  NaN
# med_sickdays_hhave                       NaN                    0
# med_healthconsult                        NaN                  NaN
# med_vacc_newborns                          1                    1
# med_child_check                            1                    1
# med_u5_deaths                            NaN                  NaN
# ed_expenses                              NaN              20.1794
# ed_expenses_perkid                       NaN              10.0897
# ed_schoolattend                          NaN                  0.5
# ed_sch_missedpc                          NaN                  1.5
# ed_work_act_pc                           NaN                    0
# labor_primary                              0                    0
# wage_expenditures                          0                    0
# durable_investment                         0              778.112
# nondurable_investment                      0              69.2198
# given_mpesa                                0                    0
# amount_given_mpesa                         0                    0
# received_mpesa                             0                    0
# amount_received_mpesa                8.00768                    0
# net_mpesa                            8.00768                    0
# saved_mpesa                                1                    1
# amount_saved_mpesa                         0               1.2492
# early_survey                               0                    0
# depressed                                  0                    0
# day_of_week                                5                    0
#
#                                            4                    5  \
# surveyid                                 806                  483
# village                                   42                   25
# survey_date              2061-09-12 00:00:00  2061-09-08 00:00:00
# femaleres                                  0                    1
# age                                       59                   35
# married                                    0                    1
# children                                   4                    6
# hhsize                                     6                    8
# edu                                       10                   10
# hh_children                                4                    6
# hh_totalmembers                            6                    8
# cons_nondurable                      258.672              63.7908
# asset_livestock                      8.26063              359.375
# asset_durable                        173.527              73.6707
# asset_phone                          19.2184                    0
# asset_savings                              0                    0
# asset_land_owned_total                   0.5                  1.7
# asset_niceroof                             0                    0
# cons_allfood                         173.011              40.9383
# cons_ownfood                        0.870168              2.26884
# cons_alcohol                               0                  NaN
# cons_tobacco                               0               5.5825
# cons_med_total                      0.800768                    0
# cons_med_children                   0.800768                    0
# cons_ed                              2.26884              2.66923
# cons_social                          8.08776              3.06961
# cons_other                           74.5035              11.5311
# ent_wagelabor                              1                    0
# ent_ownfarm                                0                    1
# ent_business                               0                    0
# ...                                      ...                  ...
# med_expenses_hh_ep                       NaN              1.60154
# med_expenses_sp_ep                       NaN                  NaN
# med_expenses_child_ep                1.23318                  NaN
# med_portion_sickinjured             0.333333                0.125
# med_port_sick_child                     0.25                    0
# med_afford_port                          0.5                    1
# med_sickdays_hhave                   1.16667                0.875
# med_healthconsult                          1                    0
# med_vacc_newborns                          1                    1
# med_child_check                            1                    1
# med_u5_deaths                            NaN                  NaN
# ed_expenses                          27.2261              32.0307
# ed_expenses_perkid                   6.80653              6.40615
# ed_schoolattend                         0.75                  0.8
# ed_sch_missedpc                         1.75                    0
# ed_work_act_pc                          1.25                  1.5
# labor_primary                              1                    0
# wage_expenditures                          0                    0
# durable_investment                   201.006              444.256
# nondurable_investment                4.34194              7.66291
# given_mpesa                                0                    0
# amount_given_mpesa                         0                    0
# received_mpesa                             0                    0
# amount_received_mpesa                      0                    0
# net_mpesa                                  0                    0
# saved_mpesa                                0                    0
# amount_saved_mpesa                         0                    0
# early_survey                               0                    0
# depressed                                  0                    0
# day_of_week                                3                    6
#
#                                            6                    7  \
# surveyid                                 849                 1386
# village                                  130                   72
# survey_date              2061-10-31 00:00:00  2061-09-03 00:00:00
# femaleres                                  0                    1
# age                                       34                   21
# married                                    0                    1
# children                                   1                    2
# hhsize                                     3                    4
# edu                                        9                   10
# hh_children                                1                    2
# hh_totalmembers                            3                    4
# cons_nondurable                      60.6144               118.07
# asset_livestock                      4.13031              120.136
# asset_durable                         219.25              203.235
# asset_phone                                0              67.2646
# asset_savings                              0              48.0461
# asset_land_owned_total                     1                    0
# asset_niceroof                             0                    0
# cons_allfood                         48.9632              108.568
# cons_ownfood                        0.266923              6.09919
# cons_alcohol                               0                    0
# cons_tobacco                               0                    0
# cons_med_total                      0.160154                    0
# cons_med_children                   0.160154                    0
# cons_ed                             0.533846              2.85607
# cons_social                        0.0667307             0.800768
# cons_other                           10.8905              5.84561
# ent_wagelabor                              0                    0
# ent_ownfarm                                0                    0
# ent_business                               0                    1
# ...                                      ...                  ...
# med_expenses_hh_ep                 0.0533846             0.800768
# med_expenses_sp_ep                       NaN                  NaN
# med_expenses_child_ep               0.160154             0.800768
# med_portion_sickinjured                    1                  0.5
# med_port_sick_child                        1                  0.5
# med_afford_port                     0.333333                    1
# med_sickdays_hhave                         0                 0.25
# med_healthconsult                          0                    1
# med_vacc_newborns                          1                    1
# med_child_check                            1                    1
# med_u5_deaths                            NaN                  NaN
# ed_expenses                          6.40615              34.2729
# ed_expenses_perkid                   6.40615              17.1364
# ed_schoolattend                            1                  0.5
# ed_sch_missedpc                            0                    0
# ed_work_act_pc                             1                  NaN
# labor_primary                              0                    0
# wage_expenditures                          0                    0
# durable_investment                   225.623              339.227
# nondurable_investment               0.556089              54.6002
# given_mpesa                                0                    0
# amount_given_mpesa                         0                    0
# received_mpesa                             0                    0
# amount_received_mpesa                      0                    0
# net_mpesa                                  0                    0
# saved_mpesa                                0                    0
# amount_saved_mpesa                         0                    0
# early_survey                               0                    0
# depressed                                  1                    0
# day_of_week                                3                    1
#
#                                            8                    9
# surveyid                                 930                  390
# village                                  195                   33
# survey_date              2061-11-12 00:00:00  2061-11-28 00:00:00
# femaleres                                  1                    1
# age                                       32                   29
# married                                    1                    1
# children                                   7                    4
# hhsize                                     9                    6
# edu                                        9                   10
# hh_children                                7                    0
# hh_totalmembers                            9                  NaN
# cons_nondurable                      581.574                    0
# asset_livestock                      1108.76                    0
# asset_durable                        252.242                    0
# asset_phone                          24.0231                    0
# asset_savings                        80.0769                    0
# asset_land_owned_total                     4                    0
# asset_niceroof                             0                    0
# cons_allfood                         469.093                    0
# cons_ownfood                         40.5723                    0
# cons_alcohol                               0                    0
# cons_tobacco                               0                    0
# cons_med_total                             0                    0
# cons_med_children                          0                  NaN
# cons_ed                              15.1345                    0
# cons_social                          30.1623                    0
# cons_other                           67.1845                    0
# ent_wagelabor                              1                    0
# ent_ownfarm                                0                    0
# ent_business                               0                    0
# ...                                      ...                  ...
# med_expenses_hh_ep                       NaN                  NaN
# med_expenses_sp_ep                       NaN                  NaN
# med_expenses_child_ep                2.40231                  NaN
# med_portion_sickinjured             0.111111                  NaN
# med_port_sick_child                 0.142857                  NaN
# med_afford_port                            1                  NaN
# med_sickdays_hhave                  0.111111                  NaN
# med_healthconsult                          0                  NaN
# med_vacc_newborns                          1                    1
# med_child_check                            1                    1
# med_u5_deaths                            NaN                  NaN
# ed_expenses                          181.614                  NaN
# ed_expenses_perkid                    30.269                  NaN
# ed_schoolattend                     0.666667                  NaN
# ed_sch_missedpc                     0.166667                  NaN
# ed_work_act_pc                             1                  NaN
# labor_primary                              1                    0
# wage_expenditures                          0                    0
# durable_investment                   1401.84                    0
# nondurable_investment                151.176                    0
# given_mpesa                                0                    0
# amount_given_mpesa                         0                    0
# received_mpesa                             0                    0
# amount_received_mpesa                      0                    0
# net_mpesa                                  0                    0
# saved_mpesa                                0                    0
# amount_saved_mpesa                         0                    0
# early_survey                               0                    0
# depressed                                  0                    0
# day_of_week                                1                    3
#
# [75 rows x 10 columns]

# %%
add_datepart(df_raw, 'survey_date')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3ee552361f45> in <module>()
# ----> 1 add_datepart(df_raw, 'survey_date')
#
# NameError: name 'add_datepart' is not defined
